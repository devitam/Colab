# %% [markdown]
# Pregunta 1

# %%
def displayPerson(*args): # Comment
    for i in args:
        print(i)

displayPerson(name="Emma", age="25")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b2e5b2b8211f> in <module>()
#       3         print(i)
#       4
# ----> 5 displayPerson(name="Emma", age="25")
#
# TypeError: displayPerson() got an unexpected keyword argument 'name'

# %% [markdown]
# Pregunta 2

# %%
def fun1(num):
    return num + 25

fun1(5)
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a0a88c5ec691> in <module>()
#       3
#       4 fun1(5)
# ----> 5 print(num)
#
# NameError: name 'num' is not defined

# %% [markdown]
# Pregunta 3

# %%
def add(a, b):
    return a+5, b+5

result = add(3, 2)
print(result)
# Out:
# (8, 7)

# %% [markdown]
# Pregunta 5

# %%
def fun1(name, age):
    print(name, age)

fun1("Emma", age=23)
fun1(age =23, name="Emma")
#fun1(age =23, “Emma”)
#fun1(name=”Emma”, 23)
# Out:
# Emma 23
# Emma 23

# %% [markdown]
# Pregunta 6

# %%
def fun1(name, age=20):
    print(name, age)

fun1('Emma', 25)
# Out:
# Emma 25

# %% [markdown]
# Pregunta 8

# %%
def outerFun(a, b):
    def innerFun(c, d):
        return c + d
    return innerFun(a, b)

res = outerFun(5, 10)
print(res)
# Out:
# 15

# %% [markdown]
# Pregunta 9

# %%
def outerFun(a, b):
    def innerFun(c, d):
        return c + d
    return innerFun(a, b)
    return a

result = outerFun(5, 10)
print(result)
# Out:
# 15

# %% [markdown]
# Pregunta 11

# %%
def display(**kwargs):
    for i in kwargs:
        print(i)
display(emp="Kelly", salary=9000)
# Out:
# emp
# salary

# %% [markdown]
# Pregunta 12

# %%
def fun1(*data)
fun1(25, 75, 55)
fun1(10, 20)
# Out:
#   File "<ipython-input-29-9673191b8412>", line 1
#     def fun1(*data)
#                    ^
# SyntaxError: invalid syntax
